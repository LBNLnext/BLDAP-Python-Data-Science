# %% [markdown]
# # Pandas DataFrames
#
#
#
# ---
#
# ### Table of Contents
#
# 1 - [Manipulating Columns ](#section1)<br>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 1.1 - [Indexing &  Slicing in Pandas](#subsection1)<br>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 1.2 - [Uniqueness](#subsection2)<br>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 1.3 - [Frequencies](#subsection3)<br>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 1.4 - [Sorting](#subsection4)<br>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 1.5 - [Min, Max, Range](#subsection5)<br>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 1.6 - [Missing Values](#subsection6)<br>
#
#
# 2 - [Booleans & Boolean Indexing](#section2)<br>
#
#
# ---

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Let's begin by reading a new data set from the file `internet_world_data.csv`. We will use `pd.read_csv` just as we did before. We will use the keyword `index_col` to set the column 'Country' as our index. In addition, we will drop the column 'S.NO' and make sure the columns 'Internet users' and 'Population' will be in float data types so they are easier to work with in this notebook.
#
# You can learn more about the data [here](https://www.kaggle.com/datasets/ramjasmaurya/1-gb-internet-price).

# %%
internet = pd.read_csv('data/internet_world_data.csv', index_col='Country')

internet = internet.drop('S.NO', axis=1)
internet['Internet users'] = internet['Internet users'].str.replace(',','')
internet['Internet users'] = internet['Internet users'].astype(float)
internet['Population'] = internet['Population'].str.replace(',','')
internet['Population'] = internet['Population'].astype(float)

# %% [markdown]
# In the five cells below, use some functions on the dataframe `internet` to do some **Exploratory Data Analysis** to explore the data!
#
# _You can always look back in Notebook 06 for ideas._

# %%
#Exploratory Data Analysis 1

#This can be head, tail, info, columns, describe, mean, median, mode, etc.

internet.head()
# Out:
#            Country code  Continental region  NO. OF Internet Plans  \
# Country
# Israel               IL           NEAR EAST                   27.0
# Kyrgyzstan           KG   CIS (FORMER USSR)                   20.0
# Fiji                 FJ             OCEANIA                   18.0
# Italy                IT      WESTERN EUROPE                   29.0
# Sudan                SD  SUB-SAHARAN AFRICA                   33.0
#
#            Average price of 1GB (USD)  Cheapest 1GB for 30 days (USD)  \
# Country
# Israel                           0.05                            0.02
# Kyrgyzstan                       0.15                            0.10
# Fiji                             0.19                            0.05
# Italy                            0.27                            0.09
# Sudan                            0.27                            0.03
#
#             Most expensive 1GB (USD)  \
# Country
# Israel                         20.95
# Kyrgyzstan                      7.08
# Fiji                            0.85
# Italy                           3.54
# Sudan                           0.92
#
#            Average price of 1GB (USD  at the start of 2021)  \
# Country
# Israel                                                 0.11
# Kyrgyzstan                                             0.21
# Fiji                                                   0.59
# Italy                                                  0.43
# Sudan                                                  0.63
#
#            Average price of 1GB (USD – at start of 2020)  Internet users  \
# Country
# Israel                                               0.9       6788737.0
# Kyrgyzstan                                          0.27       2309235.0
# Fiji                                                3.57        452479.0
# Italy                                               1.73      50540000.0
# Sudan                                               0.68      12512639.0
#
#             Population  Avg \n(Mbit/s)Ookla
# Country
# Israel       8381516.0                28.01
# Kyrgyzstan   6304030.0                16.30
# Fiji          883483.0                25.99
# Italy       60627291.0                37.15
# Sudan       41801533.0                 9.50

# %%
#Exploratory Data Analysis 2

internet.tail()
# Out:
#                                  Country code  Continental region  \
# Country
# Vatican City (Holy See)                    VA              Europe
# Venezuela                                  VE       SOUTH AMERICA
# Wallis and Futuna                          WF             OCEANIA
# Democratic Republic of the Congo           CD  SUB-SAHARAN AFRICA
# Zimbabwe                                   ZW  SUB-SAHARAN AFRICA
#
#                                   NO. OF Internet Plans  \
# Country
# Vatican City (Holy See)                             NaN
# Venezuela                                           NaN
# Wallis and Futuna                                   NaN
# Democratic Republic of the Congo                    NaN
# Zimbabwe                                            NaN
#
#                                                 Average price of 1GB (USD)  \
# Country
# Vatican City (Holy See)                                       NO PROVIDERS
# Venezuela                                                   HYPERINFLATION
# Wallis and Futuna                                             NO PROVIDERS
# Democratic Republic of the Congo  Prices listed in non-convertible 'units'
# Zimbabwe                                         UNRELIABLE EXCHANGE RATES
#
#                                   Cheapest 1GB for 30 days (USD)  \
# Country
# Vatican City (Holy See)                                      NaN
# Venezuela                                                    NaN
# Wallis and Futuna                                            NaN
# Democratic Republic of the Congo                             NaN
# Zimbabwe                                                     NaN
#
#                                   Most expensive 1GB (USD)  \
# Country
# Vatican City (Holy See)                                NaN
# Venezuela                                              NaN
# Wallis and Futuna                                      NaN
# Democratic Republic of the Congo                       NaN
# Zimbabwe                                               NaN
#
#                                  Average price of 1GB (USD  at the start of 2021)  \
# Country
# Vatican City (Holy See)                                                       NaN
# Venezuela                                                                     NaN
# Wallis and Futuna                                                             NaN
# Democratic Republic of the Congo                                              NaN
# Zimbabwe                                                                      NaN
#
#                                  Average price of 1GB (USD – at start of 2020)  \
# Country
# Vatican City (Holy See)                                                    NaN
# Venezuela                                                                  NaN
# Wallis and Futuna                                                          NaN
# Democratic Republic of the Congo                                           NaN
# Zimbabwe                                                                   NaN
#
#                                   Internet users  Population  \
# Country
# Vatican City (Holy See)                      NaN         NaN
# Venezuela                             20564451.0  28887118.0
# Wallis and Futuna                         1383.0     11661.0
# Democratic Republic of the Congo       7011507.0  84068091.0
# Zimbabwe                               4472992.0  14438802.0
#
#                                   Avg \n(Mbit/s)Ookla
# Country
# Vatican City (Holy See)                           NaN
# Venezuela                                        5.68
# Wallis and Futuna                                 NaN
# Democratic Republic of the Congo                12.08
# Zimbabwe                                        13.99

# %%
#Exploratory Data Analysis 3

internet.describe(include='all')
# Out:
#        Country code  Continental region  NO. OF Internet Plans  \
# count           242                 242             231.000000
# unique          239                  14                    NaN
# top              CW  SUB-SAHARAN AFRICA                    NaN
# freq              2                  49                    NaN
# mean            NaN                 NaN              26.610390
# std             NaN                 NaN              16.457446
# min             NaN                 NaN               1.000000
# 25%             NaN                 NaN              15.000000
# 50%             NaN                 NaN              22.000000
# 75%             NaN                 NaN              36.000000
# max             NaN                 NaN              60.000000
#
#        Average price of 1GB (USD)  Cheapest 1GB for 30 days (USD)  \
# count                         242                      231.000000
# unique                        198                             NaN
# top                  NO PROVIDERS                             NaN
# freq                            8                             NaN
# mean                          NaN                        1.718442
# std                           NaN                        4.764523
# min                           NaN                        0.000000
# 25%                           NaN                        0.215000
# 50%                           NaN                        0.630000
# 75%                           NaN                        1.370000
# max                           NaN                       45.160000
#
#         Most expensive 1GB (USD)  \
# count                 231.000000
# unique                       NaN
# top                          NaN
# freq                         NaN
# mean                   29.664848
# std                    59.235115
# min                     0.630000
# 25%                     5.905000
# 50%                    12.500000
# 75%                    34.290000
# max                   768.870000
#
#        Average price of 1GB (USD  at the start of 2021)  \
# count                                               231
# unique                                              192
# top                                                1.12
# freq                                                  3
# mean                                                NaN
# std                                                 NaN
# min                                                 NaN
# 25%                                                 NaN
# 50%                                                 NaN
# 75%                                                 NaN
# max                                                 NaN
#
#        Average price of 1GB (USD – at start of 2020)  Internet users  \
# count                                            231    2.120000e+02
# unique                                           213             NaN
# top                                             5.56             NaN
# freq                                               3             NaN
# mean                                             NaN    2.344487e+07
# std                                              NaN    9.521318e+07
# min                                              NaN    1.034000e+03
# 25%                                              NaN    3.535095e+05
# 50%                                              NaN    2.661349e+06
# 75%                                              NaN    9.671491e+06
# max                                              NaN    1.010740e+09
#
#           Population  Avg \n(Mbit/s)Ookla
# count   2.100000e+02           141.000000
# unique           NaN                  NaN
# top              NaN                  NaN
# freq             NaN                  NaN
# mean    3.623886e+07            37.275674
# std     1.404880e+08            28.669584
# min     1.620000e+03             4.890000
# 25%     1.003262e+06            16.730000
# 50%     7.003837e+06            27.840000
# 75%     2.502646e+07            49.660000
# max     1.427648e+09           135.350000

# %%
#Exploratory Data Analysis 4

internet.mean()
#internet['NO. OF Internet Plans'].mean()
# Out:
# <ipython-input-50-a9807c417270>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   internet.mean()
# NO. OF Internet Plans             2.661039e+01
# Cheapest 1GB for 30 days (USD)    1.718442e+00
# Most expensive 1GB (USD)          2.966485e+01
# Internet users                    2.344487e+07
# Population                        3.623886e+07
# Avg \n(Mbit/s)Ookla               3.727567e+01
# dtype: float64

# %%
#Exploratory Data Analysis 5

internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 242 entries, Israel to Zimbabwe
# Data columns (total 11 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Country code                                      242 non-null    object
#  1   Continental region                                242 non-null    object
#  2   NO. OF Internet Plans                             231 non-null    float64
#  3   Average price of 1GB (USD)                        242 non-null    object
#  4   Cheapest 1GB for 30 days (USD)                    231 non-null    float64
#  5   Most expensive 1GB (USD)                          231 non-null    float64
#  6   Average price of 1GB (USD  at the start of 2021)  231 non-null    object
#  7   Average price of 1GB (USD – at start of 2020)     231 non-null    object
#  8   Internet users                                    212 non-null    float64
#  9   Population                                        210 non-null    float64
#  10  Avg
# (Mbit/s)Ookla                                141 non-null    float64
# dtypes: float64(6), object(5)
# memory usage: 22.7+ KB

# %% [markdown]
# ## 1. Manipulating Columns
#  <a id='Section1'></a>

# %% [markdown]
# ### 1.1 Indexing &  Slicing  <a id='subsection1'></a>

# %% [markdown]
# There are two main ways of indexing through DataFrames. We can still use our old friend, the square brackets [ : ], or we can use it with the help of two functions: **loc** and **iloc**.
#
# **loc**: uses names or labels of rows and columns.
# **iloc**: uses indices of rows and columns. You can think of *iloc* as *index-loc*.
#
#
# Let's start with loc:
#
# #### .loc[rows-label(s), columns-label(s)]
# `.loc` Helps us view and index our DataFrame.
# * It works with string labels. Notice that most of the times you will have specific column names, but our row names often come as a number. Hence the label of the rows will be a number.
# * It can take
#     * one label __(df.loc[row-label, 'col-label-1'])__
#     * a list of labels __(df.loc[[row-label 1, row-label-2, row-label-4],['col-label-1',  'col-label-2', 'col-label-4']])__
#     * or a _slice_ of labels __(df.loc[row label-50 : row-label-100,'col-label-1': 'col-label-8'])__
#
#
# **Remember!** `loc` is **inclusive**, `iloc` is **exclusive** for its stop index.

# %% [markdown]
# We can still iterate through our DataFrame (aka table) with square brackets, by identifying the column name.

# %%
# EXAMPLE

internet["Average price of 1GB (USD)"]
# Out:
# Country
# Israel                                                                  0.05
# Kyrgyzstan                                                              0.15
# Fiji                                                                    0.19
# Italy                                                                   0.27
# Sudan                                                                   0.27
#                                                       ...
# Vatican City (Holy See)                                         NO PROVIDERS
# Venezuela                                                     HYPERINFLATION
# Wallis and Futuna                                               NO PROVIDERS
# Democratic Republic of the Congo    Prices listed in non-convertible 'units'
# Zimbabwe                                           UNRELIABLE EXCHANGE RATES
# Name: Average price of 1GB (USD), Length: 242, dtype: object

# %% [markdown]
# So why would we want to opt out of this option and switch to `loc` and `iloc`? There are a few reasons for that, and the main being compute time. With the examples we use in this notebook, it will be impossible to notice the difference, but once we get to DataFrames with hundreds of thousands or millions of values, this will become important!
#
# On a climate care note, increased compute time leads to increased electricity and data server use, which contributes to climate change! And that's part of the reason we need to consider compute time. So let's dive into learning how to use our helpers `loc` and `iloc` to be more climate conscious.

# %% [markdown]
# #### Rows

# %% [markdown]
# Let's use loc to see what are the values in the row on 'Japan' in our DataFrame.

# %%
# EXAMPLE

internet.loc['Japan']
# Out:
# Country code                                                          JP
# Continental region                                  ASIA (EX. NEAR EAST)
# NO. OF Internet Plans                                               35.0
# Average price of 1GB (USD)                                          3.38
# Cheapest 1GB for 30 days (USD)                                      0.88
# Most expensive 1GB (USD)                                           45.53
# Average price of 1GB (USD  at the start of 2021)                    3.91
# Average price of 1GB (USD – at start of 2020)                       10.4
# Internet users                                               117400000.0
# Population                                                   127202192.0
# Avg \n(Mbit/s)Ookla                                                44.05
# Name: Japan, dtype: object

# %%
#Try using loc to find data on the United States
internet.loc['United States']
# Out:
# Country code                                                      US
# Continental region                                  NORTHERN AMERICA
# NO. OF Internet Plans                                           45.0
# Average price of 1GB (USD)                                      3.33
# Cheapest 1GB for 30 days (USD)                                   1.0
# Most expensive 1GB (USD)                                        30.0
# Average price of 1GB (USD  at the start of 2021)                   8
# Average price of 1GB (USD – at start of 2020)                   8.34
# Internet users                                           312320000.0
# Population                                               327096265.0
# Avg \n(Mbit/s)Ookla                                            61.12
# Name: United States, dtype: object

# %%
#Use loc to find data on the country of your choice!
internet.loc['Poland']
# Out:
# Country code                                                    PL
# Continental region                                  EASTERN EUROPE
# NO. OF Internet Plans                                         60.0
# Average price of 1GB (USD)                                    0.64
# Cheapest 1GB for 30 days (USD)                                0.03
# Most expensive 1GB (USD)                                     23.02
# Average price of 1GB (USD  at the start of 2021)               0.7
# Average price of 1GB (USD – at start of 2020)                 1.32
# Internet users                                          34697848.0
# Population                                              37921592.0
# Avg \n(Mbit/s)Ookla                                          40.14
# Name: Poland, dtype: object

# %% [markdown]
# `iloc` uses **indices** instead of labels. Try running the cell below:

# %%
internet.iloc[10]
# Out:
# Country code                                                    FR
# Continental region                                  WESTERN EUROPE
# NO. OF Internet Plans                                         45.0
# Average price of 1GB (USD)                                    0.41
# Cheapest 1GB for 30 days (USD)                                0.09
# Most expensive 1GB (USD)                                     118.2
# Average price of 1GB (USD  at the start of 2021)              0.81
# Average price of 1GB (USD – at start of 2020)                 1.21
# Internet users                                          59470000.0
# Population                                              64990511.0
# Avg \n(Mbit/s)Ookla                                          60.94
# Name: France, dtype: object

# %% [markdown]
# You can pass in indices as a list to return a dataframe instead of a series, as you can see in the cell below:

# %%
internet.iloc[[10]]
# Out:
#         Country code Continental region  NO. OF Internet Plans  \
# Country
# France            FR     WESTERN EUROPE                   45.0
#
#         Average price of 1GB (USD)  Cheapest 1GB for 30 days (USD)  \
# Country
# France                        0.41                            0.09
#
#          Most expensive 1GB (USD)  \
# Country
# France                      118.2
#
#         Average price of 1GB (USD  at the start of 2021)  \
# Country
# France                                              0.81
#
#         Average price of 1GB (USD – at start of 2020)  Internet users  \
# Country
# France                                           1.21      59470000.0
#
#          Population  Avg \n(Mbit/s)Ookla
# Country
# France   64990511.0                60.94

# %%
#EXERCISE - Use iloc to grab information on the country found at index 50

internet.iloc[[50]] #or internet.iloc[50]
# Out:
#           Country code Continental region  NO. OF Internet Plans  \
# Country
# Nicaragua           NI    CENTRAL AMERICA                   30.0
#
#           Average price of 1GB (USD)  Cheapest 1GB for 30 days (USD)  \
# Country
# Nicaragua                       0.94                            0.02
#
#            Most expensive 1GB (USD)  \
# Country
# Nicaragua                      2.82
#
#           Average price of 1GB (USD  at the start of 2021)  \
# Country
# Nicaragua                                             1.71
#
#           Average price of 1GB (USD – at start of 2020)  Internet users  \
# Country
# Nicaragua                                         65.83       1732218.0
#
#            Population  Avg \n(Mbit/s)Ookla
# Country
# Nicaragua   6465501.0                 18.3

# %% [markdown]
# You can also grab specific rows by passing a list of indices:

# %%
internet.iloc[[1,3,6,8,9]]
# Out:
#            Country code    Continental region  NO. OF Internet Plans  \
# Country
# Kyrgyzstan           KG     CIS (FORMER USSR)                   20.0
# Italy                IT        WESTERN EUROPE                   29.0
# Moldova              MD        EASTERN EUROPE                   18.0
# Sri Lanka            LK  ASIA (EX. NEAR EAST)                   60.0
# Chile                CL         SOUTH AMERICA                   59.0
#
#            Average price of 1GB (USD)  Cheapest 1GB for 30 days (USD)  \
# Country
# Kyrgyzstan                       0.15                            0.10
# Italy                            0.27                            0.09
# Moldova                          0.32                            0.07
# Sri Lanka                        0.38                            0.00
# Chile                            0.39                            0.24
#
#             Most expensive 1GB (USD)  \
# Country
# Kyrgyzstan                      7.08
# Italy                           3.54
# Moldova                         2.79
# Sri Lanka                       5.53
# Chile                           1.83
#
#            Average price of 1GB (USD  at the start of 2021)  \
# Country
# Kyrgyzstan                                             0.21
# Italy                                                  0.43
# Moldova                                                1.12
# Sri Lanka                                              0.51
# Chile                                                  0.71
#
#            Average price of 1GB (USD – at start of 2020)  Internet users  \
# Country
# Kyrgyzstan                                          0.27       2309235.0
# Italy                                               1.73      50540000.0
# Moldova                                             2.82       3083783.0
# Sri Lanka                                           0.78       7121116.0
# Chile                                               1.87      14864456.0
#
#             Population  Avg \n(Mbit/s)Ookla
# Country
# Kyrgyzstan   6304030.0                16.30
# Italy       60627291.0                37.15
# Moldova      4051944.0                29.46
# Sri Lanka   21228763.0                13.15
# Chile       18729160.0                22.49

# %% [markdown]
# Recall __start:stop:step__ from lists? We can also select a range of rows with a specified step value in our data DataFrame. Below we will take every 2nd element from the row 0 to row 10.
#
# **Remember `iloc` is exclusive for the stop index! In other words, it only goes until stopIndex-1**

# %%
internet.iloc[0:11:2]
# Out:
#           Country code    Continental region  NO. OF Internet Plans  \
# Country
# Israel              IL             NEAR EAST                   27.0
# Fiji                FJ               OCEANIA                   18.0
# Sudan               SD    SUB-SAHARAN AFRICA                   33.0
# Moldova             MD        EASTERN EUROPE                   18.0
# Sri Lanka           LK  ASIA (EX. NEAR EAST)                   60.0
# France              FR        WESTERN EUROPE                   45.0
#
#           Average price of 1GB (USD)  Cheapest 1GB for 30 days (USD)  \
# Country
# Israel                          0.05                            0.02
# Fiji                            0.19                            0.05
# Sudan                           0.27                            0.03
# Moldova                         0.32                            0.07
# Sri Lanka                       0.38                            0.00
# France                          0.41                            0.09
#
#            Most expensive 1GB (USD)  \
# Country
# Israel                        20.95
# Fiji                           0.85
# Sudan                          0.92
# Moldova                        2.79
# Sri Lanka                      5.53
# France                       118.20
#
#           Average price of 1GB (USD  at the start of 2021)  \
# Country
# Israel                                                0.11
# Fiji                                                  0.59
# Sudan                                                 0.63
# Moldova                                               1.12
# Sri Lanka                                             0.51
# France                                                0.81
#
#           Average price of 1GB (USD – at start of 2020)  Internet users  \
# Country
# Israel                                              0.9       6788737.0
# Fiji                                               3.57        452479.0
# Sudan                                              0.68      12512639.0
# Moldova                                            2.82       3083783.0
# Sri Lanka                                          0.78       7121116.0
# France                                             1.21      59470000.0
#
#            Population  Avg \n(Mbit/s)Ookla
# Country
# Israel      8381516.0                28.01
# Fiji         883483.0                25.99
# Sudan      41801533.0                 9.50
# Moldova     4051944.0                29.46
# Sri Lanka  21228763.0                13.15
# France     64990511.0                60.94

# %%
#EXERCISE - use iloc to get every 5th element from row 0 to row 150

internet.iloc[0:151:5]
# Out:
#                        Country code    Continental region  \
# Country
# Israel                           IL             NEAR EAST
# Russia                           RU     CIS (FORMER USSR)
# France                           FR        WESTERN EUROPE
# Algeria                          DZ       NORTHERN AFRICA
# Uzbekistan                       UZ     CIS (FORMER USSR)
# Poland                           PL        EASTERN EUROPE
# Ukraine                          UA     CIS (FORMER USSR)
# Myanmar                          MM  ASIA (EX. NEAR EAST)
# Bhutan                           BT  ASIA (EX. NEAR EAST)
# Malaysia                         MY  ASIA (EX. NEAR EAST)
# Nicaragua                        NI       CENTRAL AMERICA
# Ecuador                          EC         SOUTH AMERICA
# Djibouti                         DJ    SUB-SAHARAN AFRICA
# Romania                          RO        EASTERN EUROPE
# Niger                            NE    SUB-SAHARAN AFRICA
# Estonia                          EE               BALTICS
# Guernsey                         GG        WESTERN EUROPE
# Uganda                           UG    SUB-SAHARAN AFRICA
# East Timor                       TL  ASIA (EX. NEAR EAST)
# Dominica                         DM             CARIBBEAN
# Trinidad and Tobago              TT             CARIBBEAN
# American Samoa                   AS               OCEANIA
# Oman                             OM             NEAR EAST
# Brunei                           BN  ASIA (EX. NEAR EAST)
# Hong Kong, China                 HK  ASIA (EX. NEAR EAST)
# Bosnia and Herzegovina           BA        EASTERN EUROPE
# Liberia                          LR    SUB-SAHARAN AFRICA
# South Africa                     ZA    SUB-SAHARAN AFRICA
# Albania                          AL        EASTERN EUROPE
# Liechtenstein                    LI        WESTERN EUROPE
# Maldives                         MV  ASIA (EX. NEAR EAST)
#
#                         NO. OF Internet Plans Average price of 1GB (USD)  \
# Country
# Israel                                   27.0                       0.05
# Russia                                   22.0                       0.29
# France                                   45.0                       0.41
# Algeria                                  20.0                       0.51
# Uzbekistan                               60.0                        0.6
# Poland                                   60.0                       0.64
# Ukraine                                  19.0                       0.75
# Myanmar                                  35.0                       0.78
# Bhutan                                   42.0                       0.83
# Malaysia                                 60.0                       0.89
# Nicaragua                                30.0                       0.94
# Ecuador                                  19.0                       1.06
# Djibouti                                  7.0                       1.12
# Romania                                  16.0                       1.18
# Niger                                    22.0                       1.28
# Estonia                                  34.0                       1.39
# Guernsey                                 14.0                       1.46
# Uganda                                   60.0                       1.56
# East Timor                               15.0                       1.67
# Dominica                                 17.0                       1.76
# Trinidad and Tobago                      12.0                        1.9
# American Samoa                           11.0                          2
# Oman                                     60.0                       2.12
# Brunei                                    9.0                       2.23
# Hong Kong, China                         52.0                        2.3
# Bosnia and Herzegovina                   24.0                       2.39
# Liberia                                  40.0                       2.59
# South Africa                             60.0                       2.67
# Albania                                  32.0                        2.8
# Liechtenstein                            17.0                        3.1
# Maldives                                 23.0                       3.24
#
#                         Cheapest 1GB for 30 days (USD)  \
# Country
# Israel                                            0.02
# Russia                                            0.13
# France                                            0.09
# Algeria                                           0.16
# Uzbekistan                                        0.01
# Poland                                            0.03
# Ukraine                                           0.14
# Myanmar                                           0.00
# Bhutan                                            0.33
# Malaysia                                          0.12
# Nicaragua                                         0.02
# Ecuador                                           0.63
# Djibouti                                          0.47
# Romania                                           0.11
# Niger                                             0.47
# Estonia                                           0.35
# Guernsey                                          0.16
# Uganda                                            0.45
# East Timor                                        0.83
# Dominica                                          1.11
# Trinidad and Tobago                               0.21
# American Samoa                                    1.33
# Oman                                              0.13
# Brunei                                            1.78
# Hong Kong, China                                  0.21
# Bosnia and Herzegovina                            0.63
# Liberia                                           1.55
# South Africa                                      0.12
# Albania                                           0.72
# Liechtenstein                                     0.19
# Maldives                                          1.85
#
#                         Most expensive 1GB (USD)  \
# Country
# Israel                                     20.95
# Russia                                      1.86
# France                                    118.20
# Algeria                                     2.24
# Uzbekistan                                 23.75
# Poland                                     23.02
# Ukraine                                    35.88
# Myanmar                                    14.15
# Bhutan                                      1.06
# Malaysia                                    7.26
# Nicaragua                                   2.82
# Ecuador                                     3.00
# Djibouti                                   28.01
# Romania                                    11.83
# Niger                                      12.04
# Estonia                                    18.93
# Guernsey                                   54.84
# Uganda                                     22.71
# East Timor                                  2.50
# Dominica                                   14.62
# Trinidad and Tobago                       143.18
# American Samoa                              2.92
# Oman                                        8.67
# Brunei                                      7.43
# Hong Kong, China                           10.73
# Bosnia and Herzegovina                     21.26
# Liberia                                    20.00
# South Africa                               34.95
# Albania                                    96.39
# Liechtenstein                              24.06
# Maldives                                   12.95
#
#                        Average price of 1GB (USD  at the start of 2021)  \
# Country
# Israel                                                             0.11
# Russia                                                             0.52
# France                                                             0.81
# Algeria                                                            0.65
# Uzbekistan                                                         1.34
# Poland                                                              0.7
# Ukraine                                                            0.46
# Myanmar                                                            0.78
# Bhutan                                                             1.16
# Malaysia                                                           1.12
# Nicaragua                                                          1.71
# Ecuador                                                            3.24
# Djibouti                                                           1.12
# Romania                                                            1.03
# Niger                                                               3.3
# Estonia                                                            1.27
# Guernsey                                                           1.24
# Uganda                                                             1.62
# East Timor                                                         2.08
# Dominica                                                           4.92
# Trinidad and Tobago                                                5.92
# American Samoa                                                      2.5
# Oman                                                               4.58
# Brunei                                                             2.64
# Hong Kong, China                                                   2.55
# Bosnia and Herzegovina                                             3.04
# Liberia                                                            3.25
# South Africa                                                        4.3
# Albania                                                            2.83
# Liechtenstein                                                      4.01
# Maldives                                                           3.88
#
#                        Average price of 1GB (USD – at start of 2020)  \
# Country
# Israel                                                           0.9
# Russia                                                          0.91
# France                                                          1.21
# Algeria                                                         5.15
# Uzbekistan                                                      3.27
# Poland                                                          1.32
# Ukraine                                                         5.93
# Myanmar                                                         0.87
# Bhutan                                                          1.49
# Malaysia                                                        1.66
# Nicaragua                                                      65.83
# Ecuador                                                         6.93
# Djibouti                                                       37.92
# Romania                                                         1.89
# Niger                                                          25.52
# Estonia                                                         3.67
# Guernsey                                                        3.05
# Uganda                                                          5.02
# East Timor                                                      4.48
# Dominica                                                        14.6
# Trinidad and Tobago                                             2.69
# American Samoa                                                  1.94
# Oman                                                           11.28
# Brunei                                                          8.51
# Hong Kong, China                                                7.15
# Bosnia and Herzegovina                                          3.05
# Liberia                                                         3.75
# South Africa                                                    7.77
# Albania                                                         5.28
# Liechtenstein                                                   7.99
# Maldives                                                        5.79
#
#                         Internet users   Population  Avg \n(Mbit/s)Ookla
# Country
# Israel                       6788737.0    8381516.0                28.01
# Russia                     124000000.0  145734038.0                20.46
# France                      59470000.0   64990511.0                60.94
# Algeria                     26350000.0   42228408.0                12.44
# Uzbekistan                  16692456.0   32476244.0                13.27
# Poland                      34697848.0   37921592.0                40.14
# Ukraine                     31100000.0   44246156.0                15.62
# Myanmar                     16374103.0   53708320.0                24.06
# Bhutan                        388541.0     754388.0                  NaN
# Malaysia                    25343685.0   31528033.0                25.87
# Nicaragua                    1732218.0    6465501.0                18.30
# Ecuador                      9521056.0   17084358.0                17.70
# Djibouti                      532849.0     958923.0                  NaN
# Romania                     12545558.0   19506114.0                36.90
# Niger                        2194985.0   22442831.0                  NaN
# Estonia                      1153786.0    1322920.0                55.07
# Guernsey                           NaN          NaN                  NaN
# Uganda                      10162807.0   42729036.0                15.99
# East Timor                    356356.0    1267974.0                  NaN
# Dominica                       51467.0      71625.0                  NaN
# Trinidad and Tobago          1058744.0    1389843.0                28.37
# American Samoa                     NaN          NaN                  NaN
# Oman                         3717818.0    4829473.0                44.47
# Brunei                        406705.0     428963.0                71.38
# Hong Kong, China             6585678.0    7371730.0                47.34
# Bosnia and Herzegovina       2320000.0    3323925.0                28.49
# Liberia                       377607.0    4818973.0                  NaN
# South Africa                31858027.0   57792518.0                33.62
# Albania                      2105339.0    2882740.0                40.48
# Liechtenstein                  37201.0      37910.0                  NaN
# Maldives                      275717.0     515696.0                47.93

# %% [markdown]
# We can also use `loc` to grab columns. Don't forget that we are still using `loc`, so we will have to use column labels.

# %%
# EXAMPLE

internet.loc[:,'Most expensive 1GB (USD)']
# Out:
# Country
# Israel                              20.95
# Kyrgyzstan                           7.08
# Fiji                                 0.85
# Italy                                3.54
# Sudan                                0.92
#                                     ...
# Vatican City (Holy See)               NaN
# Venezuela                             NaN
# Wallis and Futuna                     NaN
# Democratic Republic of the Congo      NaN
# Zimbabwe                              NaN
# Name: Most expensive 1GB (USD), Length: 242, dtype: float64

# %% [markdown]
# Another way to index by only one column is by adding the column label in a list. It will return a a one-column DataFrame because we passed a list.

# %%
# EXAMPLE

internet.loc[:,['Most expensive 1GB (USD)']]
# Out:
#                                   Most expensive 1GB (USD)
# Country
# Israel                                               20.95
# Kyrgyzstan                                            7.08
# Fiji                                                  0.85
# Italy                                                 3.54
# Sudan                                                 0.92
# ...                                                    ...
# Vatican City (Holy See)                                NaN
# Venezuela                                              NaN
# Wallis and Futuna                                      NaN
# Democratic Republic of the Congo                       NaN
# Zimbabwe                                               NaN
#
# [242 rows x 1 columns]

# %% [markdown]
# Notice that here we had to specify the range of rows that we want to index that column by. We used `:` in order to return all values in the column.

# %% [markdown]
# `iloc` works just as `loc`, but instead of using labels we use the index. How would you use iloc to get the 'Most expensive 1GB (USD)' column?
#
# _Hint: If you don't remember the order of columns, create a new cell and use `.columns` on your dataframe. Remember we start counting from 0!_

# %%
# EXERCISE

#internet.columns
internet.iloc[:,5]
# Out:
# Country
# Israel                              20.95
# Kyrgyzstan                           7.08
# Fiji                                 0.85
# Italy                                3.54
# Sudan                                0.92
#                                     ...
# Vatican City (Holy See)               NaN
# Venezuela                             NaN
# Wallis and Futuna                     NaN
# Democratic Republic of the Congo      NaN
# Zimbabwe                              NaN
# Name: Most expensive 1GB (USD), Length: 242, dtype: float64

# %% [markdown]
# Just as we sliced rows, we can do the same with columns. In the cell below, use `loc` and return all rows for columns *Country code* through *NO. OF Internet Plans* (inclusive of the last column).

# %%
# EXERCISE

internet.loc[:,'Country code':'NO. OF Internet Plans']
# Out:
#                                  Country code  Continental region  \
# Country
# Israel                                     IL           NEAR EAST
# Kyrgyzstan                                 KG   CIS (FORMER USSR)
# Fiji                                       FJ             OCEANIA
# Italy                                      IT      WESTERN EUROPE
# Sudan                                      SD  SUB-SAHARAN AFRICA
# ...                                       ...                 ...
# Vatican City (Holy See)                    VA              Europe
# Venezuela                                  VE       SOUTH AMERICA
# Wallis and Futuna                          WF             OCEANIA
# Democratic Republic of the Congo           CD  SUB-SAHARAN AFRICA
# Zimbabwe                                   ZW  SUB-SAHARAN AFRICA
#
#                                   NO. OF Internet Plans
# Country
# Israel                                             27.0
# Kyrgyzstan                                         20.0
# Fiji                                               18.0
# Italy                                              29.0
# Sudan                                              33.0
# ...                                                 ...
# Vatican City (Holy See)                             NaN
# Venezuela                                           NaN
# Wallis and Futuna                                   NaN
# Democratic Republic of the Congo                    NaN
# Zimbabwe                                            NaN
#
# [242 rows x 3 columns]

# %% [markdown]
# Now do the same thing, but with `iloc`.
#
# _Remember that iloc is exclusive!_

# %%
#EXERCISE

internet.iloc[:,0:3]
# Out:
#                                  Country code  Continental region  \
# Country
# Israel                                     IL           NEAR EAST
# Kyrgyzstan                                 KG   CIS (FORMER USSR)
# Fiji                                       FJ             OCEANIA
# Italy                                      IT      WESTERN EUROPE
# Sudan                                      SD  SUB-SAHARAN AFRICA
# ...                                       ...                 ...
# Vatican City (Holy See)                    VA              Europe
# Venezuela                                  VE       SOUTH AMERICA
# Wallis and Futuna                          WF             OCEANIA
# Democratic Republic of the Congo           CD  SUB-SAHARAN AFRICA
# Zimbabwe                                   ZW  SUB-SAHARAN AFRICA
#
#                                   NO. OF Internet Plans
# Country
# Israel                                             27.0
# Kyrgyzstan                                         20.0
# Fiji                                               18.0
# Italy                                              29.0
# Sudan                                              33.0
# ...                                                 ...
# Vatican City (Holy See)                             NaN
# Venezuela                                           NaN
# Wallis and Futuna                                   NaN
# Democratic Republic of the Congo                    NaN
# Zimbabwe                                            NaN
#
# [242 rows x 3 columns]

# %% [markdown]
# ### 1.2 Uniqueness  <a id='subsection2'></a>

# %% [markdown]
# Suppose that we want to find out the number of unique continental regions in our data. The `.unique()` method allows us to check this.
#
# There are two ways to accomplish this, one is using the "dot" notation, and the other using brackets. For the most part, we will stick to the second method as it can be easy to run into errors.
#
# Method 1: **df.column_label.unique( )**
#
# Method 2: **df['column_label'].unique( )**

# %%
internet['Continental region'].unique()
# Out:
# array(['NEAR EAST', 'CIS (FORMER USSR)', 'OCEANIA', 'WESTERN EUROPE',
#        'SUB-SAHARAN AFRICA', 'EASTERN EUROPE', 'ASIA (EX. NEAR EAST)',
#        'SOUTH AMERICA', 'NORTHERN AFRICA', 'CARIBBEAN', 'CENTRAL AMERICA',
#        'BALTICS', 'NORTHERN AMERICA', 'Europe'], dtype=object)

# %% [markdown]
# We can also use the method `.nunique()` to tell us how _many_ unique items we have rather which items. An alternative way to compute this is __len(df['column_label'].nunique())__.

# %%
# EXAMPLE

internet['Continental region'].nunique()
# Out:
# 14

# %% [markdown]
# In the cell below, figure out how many unique number of internet plans there are.

# %%
# EXERCISE

internet['NO. OF Internet Plans'].nunique()
# Out:
# 55

# %% [markdown]
# ### 1.3 Frequencies  <a id='subsection3'></a>

# %% [markdown]
# Say we want to find out how many instances of each continental region exists. In this case, we would use the `.value_counts()` method. This method returns the counts for the unique values in our column.

# %%
# EXAMPLE

internet['Continental region'].value_counts()
# Out:
# SUB-SAHARAN AFRICA      49
# CARIBBEAN               32
# WESTERN EUROPE          30
# ASIA (EX. NEAR EAST)    28
# OCEANIA                 24
# NEAR EAST               16
# EASTERN EUROPE          14
# SOUTH AMERICA           14
# CIS (FORMER USSR)       11
# NORTHERN AFRICA          8
# CENTRAL AMERICA          8
# NORTHERN AMERICA         4
# BALTICS                  3
# Europe                   1
# Name: Continental region, dtype: int64

# %% [markdown]
# Now let's try to find out the counts for the number of internet plans.

# %%
# EXERCISE

internet['NO. OF Internet Plans'].value_counts()
# Out:
# 60.0    20
# 18.0    11
# 17.0    11
# 21.0    10
# 9.0      9
# 22.0     9
# 42.0     8
# 13.0     8
# 35.0     7
# 19.0     7
# 14.0     7
# 27.0     6
# 24.0     6
# 20.0     6
# 11.0     6
# 15.0     6
# 25.0     5
# 16.0     5
# 23.0     5
# 3.0      4
# 7.0      4
# 12.0     4
# 30.0     4
# 4.0      4
# 45.0     4
# 34.0     4
# 58.0     3
# 36.0     3
# 2.0      3
# 40.0     3
# 28.0     3
# 52.0     3
# 33.0     2
# 31.0     2
# 37.0     2
# 8.0      2
# 32.0     2
# 5.0      2
# 29.0     2
# 6.0      2
# 46.0     2
# 44.0     2
# 59.0     1
# 54.0     1
# 48.0     1
# 50.0     1
# 26.0     1
# 38.0     1
# 47.0     1
# 49.0     1
# 53.0     1
# 39.0     1
# 10.0     1
# 51.0     1
# 1.0      1
# Name: NO. OF Internet Plans, dtype: int64

# %% [markdown]
# ### 1.4 Sorting  <a id='subsection4'></a>

# %% [markdown]
# Notice that this method sorts our values in decreasing order? What if you had an alternative sorting that you wanted to use? Maybe you want to sort by index, that is, by alphabetical order. In this case you would want to use the `sort_index()` method as seen below.

# %%
# EXAMPLE

internet['Continental region'].value_counts().sort_index()
# Out:
# ASIA (EX. NEAR EAST)    28
# BALTICS                  3
# CARIBBEAN               32
# CENTRAL AMERICA          8
# CIS (FORMER USSR)       11
# EASTERN EUROPE          14
# Europe                   1
# NEAR EAST               16
# NORTHERN AFRICA          8
# NORTHERN AMERICA         4
# OCEANIA                 24
# SOUTH AMERICA           14
# SUB-SAHARAN AFRICA      49
# WESTERN EUROPE          30
# Name: Continental region, dtype: int64

# %% [markdown]
# If instead you wanted to sort by counts, but in ascending (from smallest to largest) order, you can use the `.sort_values()` method instead with the argument __ascending = True__.

# %%
# EXAMPLE

internet['Continental region'].value_counts().sort_values(ascending=True)
# Out:
# Europe                   1
# BALTICS                  3
# NORTHERN AMERICA         4
# NORTHERN AFRICA          8
# CENTRAL AMERICA          8
# CIS (FORMER USSR)       11
# EASTERN EUROPE          14
# SOUTH AMERICA           14
# NEAR EAST               16
# OCEANIA                 24
# ASIA (EX. NEAR EAST)    28
# WESTERN EUROPE          30
# CARIBBEAN               32
# SUB-SAHARAN AFRICA      49
# Name: Continental region, dtype: int64

# %% [markdown]
# We can also use `sort_values()` without calling `value_counts()` first. In the cell below, try using `sort_values()` for the column 'Most expensive 1GB (USD)'. Have it so that it sorts in decreasing order (highest to lowest):

# %%
# EXERCISE

internet['Most expensive 1GB (USD)'].sort_values(ascending=True)
# Out:
# Country
# San Marino                          0.63
# Fiji                                0.85
# Sudan                               0.92
# Bhutan                              1.06
# China                               1.21
#                                     ...
# Vatican City (Holy See)              NaN
# Venezuela                            NaN
# Wallis and Futuna                    NaN
# Democratic Republic of the Congo     NaN
# Zimbabwe                             NaN
# Name: Most expensive 1GB (USD), Length: 242, dtype: float64

# %% [markdown]
# You might notice that we are getting some **NaN** values! This will be revisited in section 1.6.

# %% [markdown]
# ### 1.5 Min, Max, Range  <a id='subsection5'></a>

# %% [markdown]
# Say that for our analysis we want to find out which country has the highest number of internet users and which country has the lowest number of internet users.
#
# A good starting point might be to see what the __min__ and the __max__ are for our data. We can do this by using the functions `.min()` and `.max()` respectably.

# %%
# EXAMPLE

print('Min number of users is :',internet['Internet users'].min())
print('Max number of users is :',internet['Internet users'].max())
# Out:
# Min number of users is : 1034.0
# Max number of users is : 1010740000.0

# %% [markdown]
# To get the range, all you need to do is subtract the min from the max! Let's do this in the cell below:

# %%
# EXERCISE

internet_users_max = internet['Internet users'].max()
internet_users_min = internet['Internet users'].min()
internet_users_range = internet_users_max - internet_users_min

print("The range is ", internet_users_range)
# Out:
# The range is  1010738966.0

# %% [markdown]
# Now try to find the range for *Most expensive 1GB (USD)*

# %%
#EXERCISE

expensive_GB_max = internet['Most expensive 1GB (USD)'].max()
expensive_GB_min = internet['Most expensive 1GB (USD)'].min()

expensive_GB_range = expensive_GB_max - expensive_GB_min

print("The range is ", expensive_GB_range)
# Out:
# The range is  768.24

# %% [markdown]
# ### 1.6 Missing Values  <a id='subsection6'></a>

# %% [markdown]
# A common problem that you will come across when analyzing data is **missing** data. You can check if you data set contains missing data by using the function `.isnull()`. This function returns **True** whenever a values is missing (Null, NaN) and **False** whenever it is not. We can combine this function with `.sum()` to add up all the values that are True  & False.
#
# *In Python (as in most programming languages), True is represented by 1, and False by 0. So using the `.sum()` function allows us to treat these True/False as numerical values.*

# %%
# EXAMPLE

internet.isnull().sum()
# Out:
# Country code                                          0
# Continental region                                    0
# NO. OF Internet Plans                                11
# Average price of 1GB (USD)                            0
# Cheapest 1GB for 30 days (USD)                       11
# Most expensive 1GB (USD)                             11
# Average price of 1GB (USD  at the start of 2021)     11
# Average price of 1GB (USD – at start of 2020)        11
# Internet users                                       30
# Population                                           32
# Avg \n(Mbit/s)Ookla                                 101
# dtype: int64

# %% [markdown]
# Notice that for the example above we checked for the number of missing values in each of the columns? What if you only wanted to do it for one? You can use the same methods we discuss prior, that is bracket and dot notation.

# %%
# EXAMPLE

internet['NO. OF Internet Plans'].isnull().sum()
# Out:
# 11

# %% [markdown]
# In the cell below, find the number of null values in the column *Population*.

# %%
# EXERCISE

internet['Population'].isnull().sum()
# Out:
# 32

# %% [markdown]
# However, **Null** and **NaN** are not the only ways to represent missing value. Sometimes, they can appear as 999 (commonly used in census or other data involving humans) or even -1.
#
# In this data set, you might notice that instead of numerical values there are some notes used - for example, if you look at the column *Average price of 1GB (USD)*, you will notice some countries with 'NO PROVIDERS' among other things.
#
# **Discuss:** Would these count as null values / missing data? Why or why not?

# %% [markdown]
# ## Booleans & Boolean Indexing <a id='section2'></a>

# %% [markdown]
# Suppose we only want to look at the countries that have less than 10 internet plans. We will use **boolean indexing** to create a DataFrame that meets this criteria.
#
# Boolean indexing allows us to define what kind of data we want to output. For example, we can only select rows that correspond to a specific continental region or choose the rows that are below a select number of internet plans.
#
# We will use **comparison operators** in boolean indexing - below is the table from notebook 03:
#
# |Operator| Meaning|
# |--------|---------|
# |< | less than |
# |<= | less than or equal to|
# |> | greater than |
# |>= | greater than or equal to|
# |!= | not equal to|
# |== | equal to|
#
# Often people use the term **filtering data** when using boolean indexing. It's easier to break-up boolean indexing in steps by first creating a filter that specifies your criteria, then passing that filter to your dataframe.

# %% [markdown]
# For example, let's say we only wanted to look at countries that have **less than 10 internet plans.**
#
# First, let's create a filter using the appropriate comparison operator:

# %%
# EXAMPLE

internet_plan_filter = internet['NO. OF Internet Plans'] < 10
internet_plan_filter
# Out:
# Country
# Israel                              False
# Kyrgyzstan                          False
# Fiji                                False
# Italy                               False
# Sudan                               False
#                                     ...
# Vatican City (Holy See)             False
# Venezuela                           False
# Wallis and Futuna                   False
# Democratic Republic of the Congo    False
# Zimbabwe                            False
# Name: NO. OF Internet Plans, Length: 242, dtype: bool

# %% [markdown]
# Next, we will pass this filter into our original dataframe:

# %%
#EXAMPLE

internet[internet_plan_filter]
# Out:
#                                              Country code  \
# Country
# San Marino                                             SM
# Guadeloupe                                             GP
# Monaco                                                 MC
# Djibouti                                               DJ
# Tonga                                                  TO
# French Guiana                                          GF
# Palau                                                  PW
# Ethiopia                                               ET
# Brunei                                                 BN
# Eswatini                                               SZ
# Åland Islands                                          AX
# Gibraltar                                              GI
# Congo                                                  CG
# Qatar                                                  QA
# Cook Islands                                           CK
# Greenland                                              GL
# Guinea-Bissau                                          GW
# Panama                                                 PA
# Tuvalu                                                 TV
# Andorra                                                AD
# Cuba                                                   CU
# British Indian Ocean Territory                         IO
# Nauru                                                  NR
# Micronesia                                             FM
# Cocos (Keeling) Islands                                CC
# Tokelau                                                TK
# Turkmenistan                                           TM
# Malawi                                                 MW
# Saint Helena, Ascension and Tristan da Cunha           SH
# Falkland Islands                                       FK
# Equatorial Guinea                                      GQ
#
#                                                 Continental region  \
# Country
# San Marino                                          WESTERN EUROPE
# Guadeloupe                                               CARIBBEAN
# Monaco                                              WESTERN EUROPE
# Djibouti                                        SUB-SAHARAN AFRICA
# Tonga                                                      OCEANIA
# French Guiana                                        SOUTH AMERICA
# Palau                                                      OCEANIA
# Ethiopia                                        SUB-SAHARAN AFRICA
# Brunei                                        ASIA (EX. NEAR EAST)
# Eswatini                                        SUB-SAHARAN AFRICA
# Åland Islands                                       WESTERN EUROPE
# Gibraltar                                           WESTERN EUROPE
# Congo                                           SUB-SAHARAN AFRICA
# Qatar                                                    NEAR EAST
# Cook Islands                                               OCEANIA
# Greenland                                         NORTHERN AMERICA
# Guinea-Bissau                                   SUB-SAHARAN AFRICA
# Panama                                             CENTRAL AMERICA
# Tuvalu                                                     OCEANIA
# Andorra                                             WESTERN EUROPE
# Cuba                                                     CARIBBEAN
# British Indian Ocean Territory                ASIA (EX. NEAR EAST)
# Nauru                                                      OCEANIA
# Micronesia                                                 OCEANIA
# Cocos (Keeling) Islands                                    OCEANIA
# Tokelau                                                    OCEANIA
# Turkmenistan                                     CIS (FORMER USSR)
# Malawi                                          SUB-SAHARAN AFRICA
# Saint Helena, Ascension and Tristan da Cunha    SUB-SAHARAN AFRICA
# Falkland Islands                                     SOUTH AMERICA
# Equatorial Guinea                               SUB-SAHARAN AFRICA
#
#                                               NO. OF Internet Plans  \
# Country
# San Marino                                                      2.0
# Guadeloupe                                                      9.0
# Monaco                                                          3.0
# Djibouti                                                        7.0
# Tonga                                                           2.0
# French Guiana                                                   9.0
# Palau                                                           6.0
# Ethiopia                                                        3.0
# Brunei                                                          9.0
# Eswatini                                                        9.0
# Åland Islands                                                   7.0
# Gibraltar                                                       5.0
# Congo                                                           8.0
# Qatar                                                           9.0
# Cook Islands                                                    9.0
# Greenland                                                       3.0
# Guinea-Bissau                                                   9.0
# Panama                                                          8.0
# Tuvalu                                                          9.0
# Andorra                                                         7.0
# Cuba                                                            9.0
# British Indian Ocean Territory                                  3.0
# Nauru                                                           1.0
# Micronesia                                                      7.0
# Cocos (Keeling) Islands                                         2.0
# Tokelau                                                         6.0
# Turkmenistan                                                    4.0
# Malawi                                                          5.0
# Saint Helena, Ascension and Tristan da Cunha                    4.0
# Falkland Islands                                                4.0
# Equatorial Guinea                                               4.0
#
#                                              Average price of 1GB (USD)  \
# Country
# San Marino                                                         0.43
# Guadeloupe                                                         0.89
# Monaco                                                             1.08
# Djibouti                                                           1.12
# Tonga                                                              1.28
# French Guiana                                                      1.58
# Palau                                                              1.67
# Ethiopia                                                           1.71
# Brunei                                                             2.23
# Eswatini                                                           2.24
# Åland Islands                                                      2.75
# Gibraltar                                                          2.78
# Congo                                                              2.88
# Qatar                                                               3.2
# Cook Islands                                                        3.5
# Greenland                                                          3.97
# Guinea-Bissau                                                      4.41
# Panama                                                             4.49
# Tuvalu                                                             6.35
# Andorra                                                            7.49
# Cuba                                                                7.5
# British Indian Ocean Territory                                      7.5
# Nauru                                                              7.62
# Micronesia                                                         7.85
# Cocos (Keeling) Islands                                           13.47
# Tokelau                                                           20.48
# Turkmenistan                                                      21.41
# Malawi                                                            25.46
# Saint Helena, Ascension and Tristan da Cunha                      39.87
# Falkland Islands                                                  44.56
# Equatorial Guinea                                                 49.67
#
#                                               Cheapest 1GB for 30 days (USD)  \
# Country
# San Marino                                                              0.24
# Guadeloupe                                                              0.49
# Monaco                                                                  0.84
# Djibouti                                                                0.47
# Tonga                                                                   1.09
# French Guiana                                                           0.82
# Palau                                                                   1.00
# Ethiopia                                                                1.41
# Brunei                                                                  1.78
# Eswatini                                                                0.69
# Åland Islands                                                           2.35
# Gibraltar                                                               1.67
# Congo                                                                   1.00
# Qatar                                                                   1.10
# Cook Islands                                                            1.49
# Greenland                                                               2.22
# Guinea-Bissau                                                           2.25
# Panama                                                                  2.00
# Tuvalu                                                                  5.72
# Andorra                                                                 1.06
# Cuba                                                                    3.20
# British Indian Ocean Territory                                          6.67
# Nauru                                                                   7.62
# Micronesia                                                              0.99
# Cocos (Keeling) Islands                                                 7.62
# Tokelau                                                                15.54
# Turkmenistan                                                            7.14
# Malawi                                                                 20.37
# Saint Helena, Ascension and Tristan da Cunha                           38.57
# Falkland Islands                                                       29.71
# Equatorial Guinea                                                      45.16
#
#                                               Most expensive 1GB (USD)  \
# Country
# San Marino                                                        0.63
# Guadeloupe                                                        3.55
# Monaco                                                            2.37
# Djibouti                                                         28.01
# Tonga                                                             1.46
# French Guiana                                                     5.91
# Palau                                                             2.50
# Ethiopia                                                          4.17
# Brunei                                                            7.43
# Eswatini                                                          2.80
# Åland Islands                                                     8.81
# Gibraltar                                                         2.98
# Congo                                                             7.64
# Qatar                                                             4.39
# Cook Islands                                                     11.42
# Greenland                                                        11.43
# Guinea-Bissau                                                    36.12
# Panama                                                            7.48
# Tuvalu                                                           10.17
# Andorra                                                          65.07
# Cuba                                                             12.50
# British Indian Ocean Territory                                   10.00
# Nauru                                                             7.62
# Micronesia                                                       59.16
# Cocos (Keeling) Islands                                          19.32
# Tokelau                                                          27.98
# Turkmenistan                                                     30.44
# Malawi                                                           25.46
# Saint Helena, Ascension and Tristan da Cunha                     51.42
# Falkland Islands                                                 82.26
# Equatorial Guinea                                                63.22
#
#                                              Average price of 1GB (USD  at the start of 2021)  \
# Country
# San Marino                                                                               1.16
# Guadeloupe                                                                               2.42
# Monaco                                                                                   0.98
# Djibouti                                                                                 1.12
# Tonga                                                                                    3.41
# French Guiana                                                                            3.61
# Palau                                                                                     2.5
# Ethiopia                                                                                 2.44
# Brunei                                                                                   2.64
# Eswatini                                                                                13.31
# Åland Islands                                                                            3.24
# Gibraltar                                                                                7.38
# Congo                                                                                    1.94
# Qatar                                                                                    4.12
# Cook Islands                                                                      NO PACKAGES
# Greenland                                                                                9.56
# Guinea-Bissau                                                                            4.12
# Panama                                                                                   6.69
# Tuvalu                                                                            NO PACKAGES
# Andorra                                                                                  9.54
# Cuba                                                                                    13.33
# British Indian Ocean Territory                                                            7.5
# Nauru                                                                                   30.47
# Micronesia                                                                                7.2
# Cocos (Keeling) Islands                                                                 16.98
# Tokelau                                                                                 17.75
# Turkmenistan                                                                            11.44
# Malawi                                                                                  27.41
# Saint Helena, Ascension and Tristan da Cunha                                             52.5
# Falkland Islands                                                                        40.41
# Equatorial Guinea                                                                       12.78
#
#                                              Average price of 1GB (USD – at start of 2020)  \
# Country
# San Marino                                                                            6.86
# Guadeloupe                                                                            6.06
# Monaco                                                                                1.21
# Djibouti                                                                             37.92
# Tonga                                                                                 2.92
# French Guiana                                                                        13.41
# Palau                                                                                 8.34
# Ethiopia                                                                              2.06
# Brunei                                                                                8.51
# Eswatini                                                                              5.25
# Åland Islands                                                                         4.64
# Gibraltar                                                                              3.1
# Congo                                                                                 4.57
# Qatar                                                                                12.57
# Cook Islands                                                                          5.56
# Greenland                                                                            11.12
# Guinea-Bissau                                                                        11.71
# Panama                                                                                4.69
# Tuvalu                                                                               12.42
# Andorra                                                                              12.58
# Cuba                                                                           NO PACKAGES
# British Indian Ocean Territory                                                        9.31
# Nauru                                                                                28.13
# Micronesia                                                                           12.87
# Cocos (Keeling) Islands                                                        NO PACKAGES
# Tokelau                                                                              29.96
# Turkmenistan                                                                         19.81
# Malawi                                                                                3.59
# Saint Helena, Ascension and Tristan da Cunha                                          6.04
# Falkland Islands                                                                     55.47
# Equatorial Guinea                                                                    47.39
#
#                                               Internet users   Population  \
# Country
# San Marino                                           20100.0      33785.0
# Guadeloupe                                               NaN          NaN
# Monaco                                               37553.0      38682.0
# Djibouti                                            532849.0     958923.0
# Tonga                                                44558.0     103197.0
# French Guiana                                            NaN          NaN
# Palau                                                    NaN          NaN
# Ethiopia                                          19543075.0  109224414.0
# Brunei                                              406705.0     428963.0
# Eswatini                                            414278.0    1136281.0
# Åland Islands                                            NaN          NaN
# Gibraltar                                            32494.0      33718.0
# Congo                                               455055.0    5244359.0
# Qatar                                              2532059.0    2781682.0
# Cook Islands                                             NaN          NaN
# Greenland                                            39242.0      56564.0
# Guinea-Bissau                                        73148.0    1874303.0
# Panama                                             2371852.0    4176869.0
# Tuvalu                                                5520.0      11508.0
# Andorra                                              76095.0      77006.0
# Cuba                                               5638956.0   11338134.0
# British Indian Ocean Territory                           NaN          NaN
# Nauru                                                 6475.0      10670.0
# Micronesia                                           37257.0     112640.0
# Cocos (Keeling) Islands                                  NaN          NaN
# Tokelau                                                  NaN          NaN
# Turkmenistan                                       1223591.0    5850901.0
# Malawi                                             2566126.0   18143217.0
# Saint Helena, Ascension and Tristan da Cunha          2906.0       6035.0
# Falkland Islands                                      2881.0       3234.0
# Equatorial Guinea                                   332642.0    1308975.0
#
#                                               Avg \n(Mbit/s)Ookla
# Country
# San Marino                                                    NaN
# Guadeloupe                                                    NaN
# Monaco                                                        NaN
# Djibouti                                                      NaN
# Tonga                                                         NaN
# French Guiana                                                 NaN
# Palau                                                         NaN
# Ethiopia                                                    21.08
# Brunei                                                      71.38
# Eswatini                                                      NaN
# Åland Islands                                                 NaN
# Gibraltar                                                     NaN
# Congo                                                         NaN
# Qatar                                                      120.69
# Cook Islands                                                  NaN
# Greenland                                                     NaN
# Guinea-Bissau                                                 NaN
# Panama                                                      17.03
# Tuvalu                                                        NaN
# Andorra                                                       NaN
# Cuba                                                         9.10
# British Indian Ocean Territory                                NaN
# Nauru                                                         NaN
# Micronesia                                                    NaN
# Cocos (Keeling) Islands                                       NaN
# Tokelau                                                       NaN
# Turkmenistan                                                  NaN
# Malawi                                                      17.95
# Saint Helena, Ascension and Tristan da Cunha                  NaN
# Falkland Islands                                              NaN
# Equatorial Guinea                                             NaN

# %% [markdown]
# You can see that with the filter applied, we are only looking at data of the countries that fulfill the condition of having less than 10 internet plans.
#
# In the cell below, try changing the filter so that it now only looks at countries with 50 or more internet plans:

# %%
# EXERCISE

internet_plan_filter = internet['NO. OF Internet Plans'] >= 50
internet[internet_plan_filter]
# Out:
#                      Country code    Continental region  \
# Country
# Bangladesh                     BD  ASIA (EX. NEAR EAST)
# Sri Lanka                      LK  ASIA (EX. NEAR EAST)
# Chile                          CL         SOUTH AMERICA
# Indonesia                      ID  ASIA (EX. NEAR EAST)
# Pakistan                       PK  ASIA (EX. NEAR EAST)
# Uzbekistan                     UZ     CIS (FORMER USSR)
# Turkey                         TR             NEAR EAST
# Poland                         PL        EASTERN EUROPE
# India                          IN  ASIA (EX. NEAR EAST)
# Tanzania                       TZ    SUB-SAHARAN AFRICA
# Nigeria                        NG    SUB-SAHARAN AFRICA
# Malaysia                       MY  ASIA (EX. NEAR EAST)
# Brazil                         BR         SOUTH AMERICA
# Thailand                       TH  ASIA (EX. NEAR EAST)
# Zambia                         ZM    SUB-SAHARAN AFRICA
# Austria                        AT        WESTERN EUROPE
# United Kingdom                 GB        WESTERN EUROPE
# Sweden                         SE        WESTERN EUROPE
# Saudi Arabia                   SA             NEAR EAST
# Iran                           IR  ASIA (EX. NEAR EAST)
# Uganda                         UG    SUB-SAHARAN AFRICA
# Burundi                        BI    SUB-SAHARAN AFRICA
# Oman                           OM             NEAR EAST
# Kenya                          KE    SUB-SAHARAN AFRICA
# Hong Kong, China               HK  ASIA (EX. NEAR EAST)
# South Africa                   ZA    SUB-SAHARAN AFRICA
# Colombia                       CO         SOUTH AMERICA
# Germany                        DE        WESTERN EUROPE
# Gabon                          GA    SUB-SAHARAN AFRICA
# Canada                         CA      NORTHERN AMERICA
# United Arab Emirates           AE             NEAR EAST
#
#                       NO. OF Internet Plans Average price of 1GB (USD)  \
# Country
# Bangladesh                             60.0                       0.34
# Sri Lanka                              60.0                       0.38
# Chile                                  59.0                       0.39
# Indonesia                              53.0                       0.42
# Pakistan                               60.0                       0.59
# Uzbekistan                             60.0                        0.6
# Turkey                                 60.0                       0.63
# Poland                                 60.0                       0.64
# India                                  58.0                       0.68
# Tanzania                               60.0                       0.75
# Nigeria                                60.0                       0.88
# Malaysia                               60.0                       0.89
# Brazil                                 58.0                       0.92
# Thailand                               60.0                       1.06
# Zambia                                 60.0                       1.13
# Austria                                60.0                       1.17
# United Kingdom                         60.0                       1.42
# Sweden                                 58.0                       1.45
# Saudi Arabia                           60.0                       1.47
# Iran                                   52.0                       1.52
# Uganda                                 60.0                       1.56
# Burundi                                54.0                        2.1
# Oman                                   60.0                       2.12
# Kenya                                  50.0                       2.25
# Hong Kong, China                       52.0                        2.3
# South Africa                           60.0                       2.67
# Colombia                               60.0                        2.8
# Germany                                60.0                       3.38
# Gabon                                  52.0                       4.82
# Canada                                 60.0                       5.72
# United Arab Emirates                   51.0                       7.62
#
#                       Cheapest 1GB for 30 days (USD)  \
# Country
# Bangladesh                                      0.11
# Sri Lanka                                       0.00
# Chile                                           0.24
# Indonesia                                       0.17
# Pakistan                                        0.06
# Uzbekistan                                      0.01
# Turkey                                          0.05
# Poland                                          0.03
# India                                           0.05
# Tanzania                                        0.28
# Nigeria                                         0.03
# Malaysia                                        0.12
# Brazil                                          0.18
# Thailand                                        0.34
# Zambia                                          0.01
# Austria                                         0.24
# United Kingdom                                  0.11
# Sweden                                          0.20
# Saudi Arabia                                    0.33
# Iran                                            0.22
# Uganda                                          0.45
# Burundi                                         0.09
# Oman                                            0.13
# Kenya                                           0.26
# Hong Kong, China                                0.21
# South Africa                                    0.12
# Colombia                                        0.42
# Germany                                         0.35
# Gabon                                           1.06
# Canada                                          0.80
# United Arab Emirates                            0.80
#
#                       Most expensive 1GB (USD)  \
# Country
# Bangladesh                                2.22
# Sri Lanka                                 5.53
# Chile                                     1.83
# Indonesia                                 2.94
# Pakistan                                  8.59
# Uzbekistan                               23.75
# Turkey                                    2.26
# Poland                                   23.02
# India                                     2.73
# Tanzania                                  4.31
# Nigeria                                   5.25
# Malaysia                                  7.26
# Brazil                                    2.72
# Thailand                                 10.32
# Zambia                                    6.80
# Austria                                  23.43
# United Kingdom                           71.29
# Sweden                                   75.08
# Saudi Arabia                             13.33
# Iran                                      6.21
# Uganda                                   22.71
# Burundi                                   5.12
# Oman                                      8.67
# Kenya                                    10.93
# Hong Kong, China                         10.73
# South Africa                             34.95
# Colombia                                  9.88
# Germany                                  11.83
# Gabon                                    18.06
# Canada                                   79.54
# United Arab Emirates                     34.30
#
#                      Average price of 1GB (USD  at the start of 2021)  \
# Country
# Bangladesh                                                        0.7
# Sri Lanka                                                        0.51
# Chile                                                            0.71
# Indonesia                                                        0.64
# Pakistan                                                         0.69
# Uzbekistan                                                       1.34
# Turkey                                                           0.72
# Poland                                                            0.7
# India                                                            0.09
# Tanzania                                                         0.73
# Nigeria                                                          1.39
# Malaysia                                                         1.12
# Brazil                                                           1.01
# Thailand                                                         1.23
# Zambia                                                           1.36
# Austria                                                          1.08
# United Kingdom                                                   1.39
# Sweden                                                           2.07
# Saudi Arabia                                                     2.12
# Iran                                                             0.75
# Uganda                                                           1.62
# Burundi                                                          2.12
# Oman                                                             4.58
# Kenya                                                            1.05
# Hong Kong, China                                                 2.55
# South Africa                                                      4.3
# Colombia                                                         3.46
# Germany                                                          4.06
# Gabon                                                            4.89
# Canada                                                          12.55
# United Arab Emirates                                             3.78
#
#                      Average price of 1GB (USD – at start of 2020)  \
# Country
# Bangladesh                                                    0.99
# Sri Lanka                                                     0.78
# Chile                                                         1.87
# Indonesia                                                     2.99
# Pakistan                                                      1.85
# Uzbekistan                                                    3.27
# Turkey                                                        2.25
# Poland                                                        1.32
# India                                                         0.26
# Tanzania                                                      3.71
# Nigeria                                                       7.91
# Malaysia                                                      1.66
# Brazil                                                         3.5
# Thailand                                                      2.78
# Zambia                                                        2.25
# Austria                                                       1.88
# United Kingdom                                                6.66
# Sweden                                                        3.66
# Saudi Arabia                                                  5.62
# Iran                                                          1.88
# Uganda                                                        5.02
# Burundi                                                      18.79
# Oman                                                         11.28
# Kenya                                                         2.73
# Hong Kong, China                                              7.15
# South Africa                                                  7.77
# Colombia                                                      3.22
# Germany                                                       6.96
# Gabon                                                         3.39
# Canada                                                       13.21
# United Arab Emirates                                         10.23
#
#                       Internet users    Population  Avg \n(Mbit/s)Ookla
# Country
# Bangladesh               129180000.0  1.663035e+08                10.43
# Sri Lanka                  7121116.0  2.122876e+07                13.15
# Chile                     14864456.0  1.872916e+07                22.49
# Indonesia                196000000.0  2.676705e+08                17.70
# Pakistan                 118800000.0  2.137563e+08                16.73
# Uzbekistan                16692456.0  3.247624e+07                13.27
# Turkey                    69945905.0  8.234009e+07                30.48
# Poland                    34697848.0  3.792159e+07                40.14
# India                    833710000.0  1.352642e+09                13.67
# Tanzania                  30000000.0  5.631344e+07                10.39
# Nigeria                  136203231.0  1.958747e+08                18.92
# Malaysia                  25343685.0  3.152803e+07                25.87
# Brazil                   160010801.0  2.094693e+08                22.30
# Thailand                  54043108.0  6.942845e+07                33.49
# Zambia                     4760715.0  1.735171e+07                10.36
# Austria                    7681957.0  8.891388e+06                56.60
# United Kingdom            65001016.0  6.714168e+07                48.10
# Sweden                     9554907.0  9.971638e+06                73.61
# Saudi Arabia              27048861.0  3.370276e+07               102.79
# Iran                      78086663.0  8.180019e+07                24.90
# Uganda                    10162807.0  4.272904e+07                15.99
# Burundi                     607311.0  1.117537e+07                  NaN
# Oman                       3717818.0  4.829473e+06                44.47
# Kenya                      8861485.0  5.139256e+07                16.93
# Hong Kong, China           6585678.0  7.371730e+06                47.34
# South Africa              31858027.0  5.779252e+07                33.62
# Colombia                  30548252.0  4.966105e+07                12.35
# Germany                   77794405.0  8.312442e+07                55.70
# Gabon                      1040000.0  2.119275e+06                  NaN
# Canada                    33950632.0  3.706456e+07                75.18
# United Arab Emirates       8913217.0  9.630959e+06               135.35

# %% [markdown]
# How many countries can you have 50 or more internet plans?
#
# **Hint:** you can use our old friend `len()`.

# %%
# EXERCISE

len(internet[internet_plan_filter])
# Out:
# 31

# %% [markdown]
# We can also see if rows of data fulfill multiple conditions. We can use `&` to unite them in our filter.
#
# **Note**: if we want to use two or more specifications, we need to pass each of the in a separate set of parentheses. The structure should look like this:
#
# `(argument 1) & (argument 2)`

# %% [markdown]
# In the example below, let's find countries that have 50 or more internet plans located in the continental region of Sub-Saharan Africa:

# %%
# EXAMPLE

internet_plan_filter = (internet['NO. OF Internet Plans'] >= 50) & (internet['Continental region'] == 'SUB-SAHARAN AFRICA')

internet[internet_plan_filter]
# Out:
#              Country code  Continental region  NO. OF Internet Plans  \
# Country
# Tanzania               TZ  SUB-SAHARAN AFRICA                   60.0
# Nigeria                NG  SUB-SAHARAN AFRICA                   60.0
# Zambia                 ZM  SUB-SAHARAN AFRICA                   60.0
# Uganda                 UG  SUB-SAHARAN AFRICA                   60.0
# Burundi                BI  SUB-SAHARAN AFRICA                   54.0
# Kenya                  KE  SUB-SAHARAN AFRICA                   50.0
# South Africa           ZA  SUB-SAHARAN AFRICA                   60.0
# Gabon                  GA  SUB-SAHARAN AFRICA                   52.0
#
#              Average price of 1GB (USD)  Cheapest 1GB for 30 days (USD)  \
# Country
# Tanzania                           0.75                            0.28
# Nigeria                            0.88                            0.03
# Zambia                             1.13                            0.01
# Uganda                             1.56                            0.45
# Burundi                             2.1                            0.09
# Kenya                              2.25                            0.26
# South Africa                       2.67                            0.12
# Gabon                              4.82                            1.06
#
#               Most expensive 1GB (USD)  \
# Country
# Tanzania                          4.31
# Nigeria                           5.25
# Zambia                            6.80
# Uganda                           22.71
# Burundi                           5.12
# Kenya                            10.93
# South Africa                     34.95
# Gabon                            18.06
#
#              Average price of 1GB (USD  at the start of 2021)  \
# Country
# Tanzania                                                 0.73
# Nigeria                                                  1.39
# Zambia                                                   1.36
# Uganda                                                   1.62
# Burundi                                                  2.12
# Kenya                                                    1.05
# South Africa                                              4.3
# Gabon                                                    4.89
#
#              Average price of 1GB (USD – at start of 2020)  Internet users  \
# Country
# Tanzania                                              3.71      30000000.0
# Nigeria                                               7.91     136203231.0
# Zambia                                                2.25       4760715.0
# Uganda                                                5.02      10162807.0
# Burundi                                              18.79        607311.0
# Kenya                                                 2.73       8861485.0
# South Africa                                          7.77      31858027.0
# Gabon                                                 3.39       1040000.0
#
#                Population  Avg \n(Mbit/s)Ookla
# Country
# Tanzania       56313438.0                10.39
# Nigeria       195874685.0                18.92
# Zambia         17351708.0                10.36
# Uganda         42729036.0                15.99
# Burundi        11175374.0                  NaN
# Kenya          51392565.0                16.93
# South Africa   57792518.0                33.62
# Gabon           2119275.0                  NaN

# %% [markdown]
# In the cell below, find countries in the continental region Western Europe that have a value less than 0.5 USD for the cheapest 1GB of internet for 30 days:

# %%
# EXERCISE

internet_price_filter = (internet['Cheapest 1GB for 30 days (USD)'] < 0.5) & (internet['Continental region'] == 'WESTERN EUROPE')

internet[internet_price_filter]
# Out:
#                Country code Continental region  NO. OF Internet Plans  \
# Country
# Italy                    IT     WESTERN EUROPE                   29.0
# France                   FR     WESTERN EUROPE                   45.0
# San Marino               SM     WESTERN EUROPE                    2.0
# Denmark                  DK     WESTERN EUROPE                   34.0
# Finland                  FI     WESTERN EUROPE                   18.0
# Austria                  AT     WESTERN EUROPE                   60.0
# Iceland                  IS     WESTERN EUROPE                   20.0
# United Kingdom           GB     WESTERN EUROPE                   60.0
# Ireland                  IE     WESTERN EUROPE                   12.0
# Sweden                   SE     WESTERN EUROPE                   58.0
# Guernsey                 GG     WESTERN EUROPE                   14.0
# Isle of Man              IM     WESTERN EUROPE                   14.0
# Liechtenstein            LI     WESTERN EUROPE                   17.0
# Germany                  DE     WESTERN EUROPE                   60.0
#
#                Average price of 1GB (USD)  Cheapest 1GB for 30 days (USD)  \
# Country
# Italy                                0.27                            0.09
# France                               0.41                            0.09
# San Marino                           0.43                            0.24
# Denmark                              0.79                            0.00
# Finland                              0.97                            0.26
# Austria                              1.17                            0.24
# Iceland                              1.23                            0.16
# United Kingdom                       1.42                            0.11
# Ireland                              1.42                            0.13
# Sweden                               1.45                            0.20
# Guernsey                             1.46                            0.16
# Isle of Man                           1.8                            0.42
# Liechtenstein                         3.1                            0.19
# Germany                              3.38                            0.35
#
#                 Most expensive 1GB (USD)  \
# Country
# Italy                               3.54
# France                            118.20
# San Marino                          0.63
# Denmark                             2.23
# Finland                             1.63
# Austria                            23.43
# Iceland                            17.29
# United Kingdom                     71.29
# Ireland                            11.64
# Sweden                             75.08
# Guernsey                           54.84
# Isle of Man                        34.28
# Liechtenstein                      24.06
# Germany                            11.83
#
#                Average price of 1GB (USD  at the start of 2021)  \
# Country
# Italy                                                      0.43
# France                                                     0.81
# San Marino                                                 1.16
# Denmark                                                     0.8
# Finland                                                    2.14
# Austria                                                    1.08
# Iceland                                                    1.46
# United Kingdom                                             1.39
# Ireland                                                    1.36
# Sweden                                                     2.07
# Guernsey                                                   1.24
# Isle of Man                                                1.66
# Liechtenstein                                              4.01
# Germany                                                    4.06
#
#                Average price of 1GB (USD – at start of 2020)  Internet users  \
# Country
# Italy                                                   1.73      50540000.0
# France                                                  1.21      59470000.0
# San Marino                                              6.86         20100.0
# Denmark                                                 1.36       5407278.0
# Finland                                                 1.16       4831170.0
# Austria                                                 1.88       7681957.0
# Iceland                                                 3.78        329196.0
# United Kingdom                                          6.66      65001016.0
# Ireland                                                 3.95       4024552.0
# Sweden                                                  3.66       9554907.0
# Guernsey                                                3.05             NaN
# Isle of Man                                             3.33             NaN
# Liechtenstein                                           7.99         37201.0
# Germany                                                 6.96      77794405.0
#
#                 Population  Avg \n(Mbit/s)Ookla
# Country
# Italy           60627291.0                37.15
# France          64990511.0                60.94
# San Marino         33785.0                  NaN
# Denmark          5752126.0               105.65
# Finland          5522576.0                71.23
# Austria          8891388.0                56.60
# Iceland           336713.0                  NaN
# United Kingdom  67141684.0                48.10
# Ireland          4818690.0                30.16
# Sweden           9971638.0                73.61
# Guernsey               NaN                  NaN
# Isle of Man            NaN                  NaN
# Liechtenstein      37910.0                  NaN
# Germany         83124418.0                55.70

# %% [markdown]
# In the cell below, find countries in the region South America that has a population greater than 10 million (10000000) and have less than 50 internet plans.

# %%
# EXERCISE

internet_filter = (internet['Continental region'] == 'SOUTH AMERICA') & (internet['Population'] > 10000000) & (internet['NO. OF Internet Plans'] < 50)

internet[internet_filter]
# Out:
#           Country code Continental region  NO. OF Internet Plans  \
# Country
# Ecuador             EC      SOUTH AMERICA                   19.0
# Peru                PE      SOUTH AMERICA                   49.0
# Bolivia             BO      SOUTH AMERICA                   48.0
# Argentina           AR      SOUTH AMERICA                   28.0
#
#           Average price of 1GB (USD)  Cheapest 1GB for 30 days (USD)  \
# Country
# Ecuador                         1.06                            0.63
# Peru                            1.15                            0.85
# Bolivia                         2.18                            0.87
# Argentina                       2.38                            0.44
#
#            Most expensive 1GB (USD)  \
# Country
# Ecuador                        3.00
# Peru                          15.58
# Bolivia                       14.44
# Argentina                     11.47
#
#           Average price of 1GB (USD  at the start of 2021)  \
# Country
# Ecuador                                               3.24
# Peru                                                  2.13
# Bolivia                                               5.09
# Argentina                                             1.45
#
#           Average price of 1GB (USD – at start of 2020)  Internet users  \
# Country
# Ecuador                                            6.93       9521056.0
# Peru                                               2.48      15674241.0
# Bolivia                                            5.99       4843916.0
# Argentina                                           7.4      33561876.0
#
#            Population  Avg \n(Mbit/s)Ookla
# Country
# Ecuador    17084358.0                17.70
# Peru       31989260.0                15.64
# Bolivia    11353142.0                14.10
# Argentina  44361150.0                20.64

# %% [markdown]
# ---
# Notebook developed by: Kseniya Usovich, Karla Palos, Alisa Bettale
